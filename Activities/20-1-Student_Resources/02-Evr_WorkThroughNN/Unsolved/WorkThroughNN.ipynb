# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 5)                 15
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Train on 750 samples
# Epoch 1/100
# 750/750 [==============================] - 1s 774us/sample - loss: 0.6633 - accuracy: 0.5107
# Epoch 2/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.6068 - accuracy: 0.5120
# Epoch 3/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.5579 - accuracy: 0.5200
# Epoch 4/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.5141 - accuracy: 0.6920
# Epoch 5/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.4756 - accuracy: 0.9027
# Epoch 6/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.4413 - accuracy: 0.9853
# Epoch 7/100
# 750/750 [==============================] - 0s 42us/sample - loss: 0.4103 - accuracy: 0.9987
# Epoch 8/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.3814 - accuracy: 1.0000
# Epoch 9/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.3546 - accuracy: 1.0000
# Epoch 10/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.3296 - accuracy: 0.9987
# Epoch 11/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.3062 - accuracy: 0.9973
# Epoch 12/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.2844 - accuracy: 0.9960
# Epoch 13/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.2641 - accuracy: 0.9960
# Epoch 14/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.2449 - accuracy: 0.9960
# Epoch 15/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.2272 - accuracy: 0.9960
# Epoch 16/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.2107 - accuracy: 0.9960
# Epoch 17/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.1954 - accuracy: 0.9960
# Epoch 18/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.1814 - accuracy: 0.9960
# Epoch 19/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.1684 - accuracy: 0.9960
# Epoch 20/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.1566 - accuracy: 0.9960
# Epoch 21/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.1457 - accuracy: 0.9960
# Epoch 22/100
# 750/750 [==============================] - 0s 42us/sample - loss: 0.1357 - accuracy: 0.9960
# Epoch 23/100
# 750/750 [==============================] - 0s 42us/sample - loss: 0.1266 - accuracy: 0.9960
# Epoch 24/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.1182 - accuracy: 0.9960
# Epoch 25/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.1106 - accuracy: 0.9960
# Epoch 26/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.1034 - accuracy: 0.9960
# Epoch 27/100
# 750/750 [==============================] - 0s 42us/sample - loss: 0.0969 - accuracy: 0.9960
# Epoch 28/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0908 - accuracy: 0.9973
# Epoch 29/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0853 - accuracy: 0.9987
# Epoch 30/100
# 750/750 [==============================] - 0s 42us/sample - loss: 0.0802 - accuracy: 0.9987
# Epoch 31/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.0755 - accuracy: 0.9987
# Epoch 32/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0711 - accuracy: 0.9987
# Epoch 33/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0670 - accuracy: 0.9987
# Epoch 34/100
# 750/750 [==============================] - 0s 41us/sample - loss: 0.0633 - accuracy: 1.0000
# Epoch 35/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0598 - accuracy: 1.0000
# Epoch 36/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0565 - accuracy: 1.0000
# Epoch 37/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0535 - accuracy: 1.0000
# Epoch 38/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0508 - accuracy: 1.0000
# Epoch 39/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0481 - accuracy: 1.0000
# Epoch 40/100
# 750/750 [==============================] - 0s 42us/sample - loss: 0.0457 - accuracy: 1.0000
# Epoch 41/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0434 - accuracy: 1.0000
# Epoch 42/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0413 - accuracy: 1.0000
# Epoch 43/100
# 750/750 [==============================] - 0s 46us/sample - loss: 0.0393 - accuracy: 1.0000
# Epoch 44/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0375 - accuracy: 1.0000
# Epoch 45/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0357 - accuracy: 1.0000
# Epoch 46/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0341 - accuracy: 1.0000
# Epoch 47/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0326 - accuracy: 1.0000
# Epoch 48/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0311 - accuracy: 1.0000
# Epoch 49/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0298 - accuracy: 1.0000
# Epoch 50/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0285 - accuracy: 1.0000
# Epoch 51/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0273 - accuracy: 1.0000
# Epoch 52/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0262 - accuracy: 1.0000
# Epoch 53/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0251 - accuracy: 1.0000
# Epoch 54/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0241 - accuracy: 1.0000
# Epoch 55/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0231 - accuracy: 1.0000
# Epoch 56/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0222 - accuracy: 1.0000
# Epoch 57/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0213 - accuracy: 1.0000
# Epoch 58/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0205 - accuracy: 1.0000
# Epoch 59/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0197 - accuracy: 1.0000
# Epoch 60/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0190 - accuracy: 1.0000
# Epoch 61/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0183 - accuracy: 1.0000
# Epoch 62/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0176 - accuracy: 1.0000
# Epoch 63/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0170 - accuracy: 1.0000
# Epoch 64/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0164 - accuracy: 1.0000
# Epoch 65/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0158 - accuracy: 1.0000
# Epoch 66/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0152 - accuracy: 1.0000
# Epoch 67/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0147 - accuracy: 1.0000
# Epoch 68/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0142 - accuracy: 1.0000
# Epoch 69/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0137 - accuracy: 1.0000
# Epoch 70/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0133 - accuracy: 1.0000
# Epoch 71/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0128 - accuracy: 1.0000
# Epoch 72/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0124 - accuracy: 1.0000
# Epoch 73/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0120 - accuracy: 1.0000
# Epoch 74/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0117 - accuracy: 1.0000
# Epoch 75/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0113 - accuracy: 1.0000
# Epoch 76/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0109 - accuracy: 1.0000
# Epoch 77/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0106 - accuracy: 1.0000
# Epoch 78/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0103 - accuracy: 1.0000
# Epoch 79/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0100 - accuracy: 1.0000
# Epoch 80/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0097 - accuracy: 1.0000
# Epoch 81/100
# 750/750 [==============================] - 0s 39us/sample - loss: 0.0094 - accuracy: 1.0000
# Epoch 82/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0091 - accuracy: 1.0000
# Epoch 83/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0088 - accuracy: 1.0000
# Epoch 84/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0086 - accuracy: 1.0000
# Epoch 85/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0083 - accuracy: 1.0000
# Epoch 86/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0081 - accuracy: 1.0000
# Epoch 87/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0079 - accuracy: 1.0000
# Epoch 88/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0077 - accuracy: 1.0000
# Epoch 89/100
# 750/750 [==============================] - 0s 33us/sample - loss: 0.0075 - accuracy: 1.0000
# Epoch 90/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0073 - accuracy: 1.0000
# Epoch 91/100
# 750/750 [==============================] - 0s 34us/sample - loss: 0.0071 - accuracy: 1.0000
# Epoch 92/100
# 750/750 [==============================] - 0s 34us/sample - loss: 0.0069 - accuracy: 1.0000
# Epoch 93/100
# 750/750 [==============================] - 0s 36us/sample - loss: 0.0067 - accuracy: 1.0000
# Epoch 94/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0065 - accuracy: 1.0000
# Epoch 95/100
# 750/750 [==============================] - 0s 37us/sample - loss: 0.0063 - accuracy: 1.0000
# Epoch 96/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0062 - accuracy: 1.0000
# Epoch 97/100
# 750/750 [==============================] - 0s 33us/sample - loss: 0.0060 - accuracy: 1.0000
# Epoch 98/100
# 750/750 [==============================] - 0s 40us/sample - loss: 0.0059 - accuracy: 1.0000
# Epoch 99/100
# 750/750 [==============================] - 0s 35us/sample - loss: 0.0057 - accuracy: 1.0000
# Epoch 100/100
# 750/750 [==============================] - 0s 38us/sample - loss: 0.0056 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 250/1 - 0s - loss: 0.0035 - accuracy: 1.0000
# Loss: 0.0047910214811563495, Accuracy: 1.0
